# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorHenrique01/IFB/blob/main/slidesTuplasListas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Escreva um programa que solicita que o usuário digite 5 números inteiros e os coloca em uma lista.
# Quando terminar, imprima a lista.

lista = []
for i in range(1,6):
  numero = input(f"Digite o {i} numero: ")
  lista.append(numero)

print(lista)
# Out:
# Digite o 0 numero1
# Digite o 1 numero2
# Digite o 2 numero3
# Digite o 3 numero4
# Digite o 4 numero5
# ['1', '2', '3', '4', '5']

# %%
# Escreva um programa que aplica a função módulo a todos os elementos e uma lista.

lista = [-1, -2, -3, -4, -5]
resultado = []

for i in lista:
  resultado.append(abs(i))

print(resultado)
# Out:
# [1, 2, 3, 4, 5]

# %%
# Escreva um programa que apaga todos os elementos negativos de uma lista.
